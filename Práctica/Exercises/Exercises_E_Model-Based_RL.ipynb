# %% [markdown]
# # Exercise E.01
#
# - Modify the code of Dyna-Q to plot the number of steps taken to reach the goal for each episode.
#
# - Run the algorithm with planning_steps=0 (which is equivalent to standard Q-learning) and with planning_steps=5, and show the plots of number of steps in each case.
#
# - How does the learning speed differ? Explain why adding planning steps (n > 0) leads to a faster convergence to the optimal policy.

# %% [markdown]
# # Questions E.02
#
# 1. How do Dyna-Q and I2A use the model's predictions? Is it for updating value functions directly or for generating contextual information?
#
# 2. When does each algorithm use its model? Does it simulate from the current state to look ahead or from random past states to reinforce existing knowledge?
#
# 3. Which architecture do you believe is more flexible for complex environments where a perfect model is impossible to learn? Justify your reasoning.
