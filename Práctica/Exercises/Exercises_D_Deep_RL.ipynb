# %% [markdown]
# # Question D.01
#
# Analyse the iterations per second during the training of 'Pendulum-v1' using continuous REINFORCE in notebook 07_REINFORCE_Continuous:
# 1. What happens?
# 2. Why?
# 3. What would happen if at some point we find the perfect agent?

# %% [markdown]
# # Exercise D.02
#
# Train the 'Pendulum-v1' using continuous REINFORCE in notebook (see 07_REINFORCE_Continuous) using different random seeds.
#
# Compare the convergence rate depending on different seeds.

# %% [markdown]
# # Exercise D.03
#
# Play with the hyperparmeters of the A2C algorithm for the'CartPole-v1' environment. Study specially the effects of changing the learning rate for each network. Analyze how do this parameters affect learning?

# %% [markdown]
# # Execise D.04
#
# Analyze and compare the results with A2C and PPO for CartPole. Does training benefit from the most sophisticated algorithm? How?

# %% [markdown]
# # Exercise D.05
#
# Select an environment with a continuous action space from Gymnasium (not atari) and train it using one of Stable Baselines algorithms such as PPO or SAC.

# %% [markdown]
# # Exercise D.06
#
# Train the Find Home environment using SB3. Explain the selected strategy.
